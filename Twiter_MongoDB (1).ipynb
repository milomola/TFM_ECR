# %%
import sys
import datetime
import time
import json
import pandas as pd
pd.Timestamp.now()
# Out:
# Timestamp('2022-10-30 18:52:28.697931')

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\milom\anaconda3\lib\site-packages (4.2.0)

# %%
import pymongo

# %%
# !pip install twython
# Out:
# Requirement already satisfied: twython in c:\users\milom\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in c:\users\milom\anaconda3\lib\site-packages (from twython) (1.3.1)
# Requirement already satisfied: requests>=2.1.0 in c:\users\milom\anaconda3\lib\site-packages (from twython) (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\milom\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\milom\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2021.10.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\milom\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\milom\anaconda3\lib\site-packages (from requests>=2.1.0->twython) (3.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\milom\anaconda3\lib\site-packages (from requests-oauthlib>=0.4.0->twython) (3.2.1)

# %%
from twython import Twython

# %%
import timeit

# %%
APP_KEY = 'klpDMFL3s9nFmvbLT35i7VsGN' # API Key
APP_SECRET = 'U4CJXqTcfaBXPS8rf2iZGiOWFuJKUpMr1IOndDfPUz3JHQclBN' # API Secret Key
OAUTH_TOKEN = '1389261920251883526-frxfbag986NQqBPbJ2hXSAHFQCl7Bx' # Access Token
OAUTH_TOKEN_SECRET = 'cVbpQmznRVXSRZV8oj3TnSrXOL1L8j5XyyjHmbVMnQcAR' # Access Token Secret

# %%
twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

# %%
def get_data_user_timeline_all_pages(kid, page):
    try:        
        '''
        'count' especifica el número de tweets que se deben intentar recuperar, hasta un máximo de 200
 por solicitud distinta. El valor del conteo se considera mejor como un límite para
 el número de tweets que se devolverán porque se eliminó el contenido suspendido o eliminado
 después de que el recuento ha sido aplicado Incluimos retweets en el conteo, incluso si
 include_rts no se suministra. Se recomienda que siempre envíe include_rts = 1 cuando
 utilizando este método API.
        '''
        d = twitter.get_user_timeline(screen_name=kid, count="200", page=page, include_entities="true", include_rts="1")
    except Exception as e:
        print ("Error reading id %s, exception: %s" % (kid, e))
        return None
    #print (len(d)) #Número de entradas devueltas
    # Para visualizar los campos (keys del diccionario) introducidos
    #    if len(d)>0:
    #        print ("d.keys(): ", d[0].keys())
    return d

#Para visualizar los campos (keys del diccionario) introducidos
#    if len(d)>0:
#        print ("d.keys(): ", d[0].keys())

# %%
###### PARTE 4: Configurar la base de datos Mongo y las colecciones ###### 

#Establecimiento Conexión a MongoDB Atlas


# Datos de ejemplo, necesario modificar por vuestra instancia en MongoDB Atlas o local
dbStringConnection = "mongodb+srv://DB_TFM_ECR:Acr*1003@clustertfm.ss3qq9m.mongodb.net/?retryWrites=true&w=majority"
dbName = 'DB_TFM_ECR'
dbCollectionA = 'Tweetters_acc'
dbCollectionT = 'Tweetters'

# %%
client = pymongo.MongoClient(dbStringConnection)

# Definición de la base de datos MongoDB
db = client[dbName]

# Crea la colección accounts in la base de datos para los detalles de las cuentas de twitter
accounts = db[dbCollectionA]

# Crea un índice sobre la colección de cuentas para evitar la inserción de duplicados
db[dbCollectionA].create_index([('Twitter_handle', pymongo.ASCENDING)], unique=True)

# Muestra los índices sobre la colección accounts
# list(db.accounts.index_information())

# Muestra el número de cuentas en la colección accounts
# accounts.count_documents({})

# Crea la colleción donde se insertarán los tweets
tweets = db[dbCollectionT]

# Crea un índice de unicidad en la colección tweets para evitar duplicados
db[dbCollectionT].create_index([('id_str', pymongo.ASCENDING)], unique=True)

# Muestra los índices sobre la colección tweets
# list(db.tweets.index_information())

# Muestra el número de tweets en la tabla
# tweets.count_documents({})

# Para ver el listado de las bases de datos en MongoDB
# client.database_names()

# Para ver el listado de las colecciones en la base de datos 'MLB'
# db.collection_names()
# Out:
# 'id_str_1'

# %%
###### PARTE 5: Leer las cuentas de Twitter (y añadir a MongoDB si es posible)

#Siempre trata de insertar las cuentas, si ya tenemos todas podemos cambiar a la otra versón que primero comprueba
#Substituir el fichero accountsEMBS.csv por el fichero csv propio con los datos de las cuentas de Twitter

df = pd.read_csv(r'C:\Users\milom\Desktop\TFM_Emilio_Charlo\Cuentas_Twitter_TFM.csv', encoding='latin-1')
repetidas = 0
cuentasTwitter = json.loads(df.T.to_json()).values()
print("Intentando insertar ", len(df), " cuentas de Twitter")

# Alternativa, solo leer y cargar a MongoDB sí la colleción de cuentas es vacía
if accounts.count_documents({}) < 1:
    df = pd.read_csv(r'C:\Users\milom\Desktop\TFM_Emilio_Charlo\Cuentas_Twitter_TFM.csv', encoding='latin-1')
    cuentasTwitter = json.loads(df.T.to_json()).values()
    print ("No account data in MongoDB, attempting to insert", len(cuentasTwitter), "records")
    try:
        accounts.insert_many(cuentasTwitter)
    except pymongo.errors.BulkWriteError:
        print ('BulkWriteError\n');
pass
#else:
#   print ("There are already", accounts.count_documents({}), "records in the *accounts* table")


# Listar documentos en la colección accounts
# list(accounts.find())[:1]

# Crea la lista de cuentas de twitter para descargar tweets
twitter_accounts = accounts.distinct('Twitter_URL')
#print len(twitter_accounts)
twitter_accounts[:5]
# Out:
# Intentando insertar  6  cuentas de Twitter
# ['@AJEnglish', '@BBCBreaking', '@IsraelRadar_com', '@cnnbrk', '@guardian']

# %%
###### PARTE 6: Bucle principal sobre el cual las cuentas de Twitter se añaden a la colección de cuentas en MongoDB   ######  

start_time = timeit.default_timer()

starting_count = tweets.count_documents({})

#for s in twitter_accounts[:len(twitter_accounts)]:
for s in twitter_accounts[:len(twitter_accounts)]:
    #Fija el contador de duplicados para esta cuenta de twitter a cero
    duplicates = 0
    
    #Comprueba el ratio límite de llamadas por minuto en el API de twitter (900 peticiones/15-minutos)
    rate_limit = twitter.get_application_rate_limit_status()['resources']['statuses']['/statuses/user_timeline']['remaining']
    print ('\n', rate_limit, '# llamadas a la API restantes')

    #tweet_id = str(mentions.find_one( { "query_screen_name": s}, sort=[("id_str", 1)])["id_str"])
    print ('\nLeyendo tweets enviados por: ', s, '-- index: ', twitter_accounts.index(s))
    
    page = 1
    
    #Se pueden descargar 200 tweets por llamada y hasta 3.200 tweets totales, es decir, 16 páginas por cuenta 
    while page < 17:
        print ("--- STARTING PAGE", page, '...llamadas a la API restantes estimadas: ', rate_limit)

        d = get_data_user_timeline_all_pages(s, page)          
        if not d:
            print ("No hubo tweets devueltos........Desplazandose al siguiente ID")
            break      
        if len(d)==0:    #Este registro es diferentes de las menciones y los ficheros DMS
            print ("No hubo tweets devueltos........Desplazandose al siguiente ID")
            break
        #if not d['statuses']:
        #    break
        
                
        #Decrementamos en 1 el contador rate_limit
        rate_limit -= 1
        print ('..........llamadas a la API restantes estimadas: ', rate_limit)    
    

        ##### Escribimos los datos en MongoDB -- iteramos sobre cada tweet
        for entry in d:
            datetime.datetime.now()
            #Convertimos los datos de twitter para insertarlos en Mongo
            t = json.dumps(entry)
            #print 'type(t)', type(t)                   #<type 'str'>
            loaded_entry = json.loads(t)
            #print type(loaded_entry) , loaded_entry    #<type 'dict'>
        
            #Insertamos el tweet en la base de datos -- A menos que este ya existe
            try:
                 tweets.insert_one(loaded_entry)
            except pymongo.errors.DuplicateKeyError as e:
                print (e, '\n')
                duplicates += 1
                if duplicates>9:
                    break
                pass     
        
        
        print ('--- PÁGINA FINALIZADA ', page, ' PARA ORGANIZAR ', s, "--", len(d), " TWEETS")
    
        #Si hay demasiados duplicados entonces saltamos a la siguietne cuenta 
        if duplicates > 9:
            print ('\n********************Hay %s' % duplicates, 'duplicados....saltando al siguiente ID ********************\n')
            #continue        
            break
                    
        page += 1
        if page > 16:
            print ("NO SE ENCUENTRA AL FINAL DE LA PÁGINA 16")
            break    
                
        # ESTE ES UN MÉTODO CRUDO QUE PONE EN UN CONTROL DE LÍMITE DE TASA API
        # EL LÍMITE DE VELOCIDAD PARA COMPROBAR CUÁNTAS SON LAS LLAMADAS DE API SON 180, LO QUE SIGNIFICA QUE NO PODEMOS
        if rate_limit < 5:
            print ('Se estiman menos de 5 llamadas API ... verifique y haga una pausa de 5 minutos si es necesario')
            rate_limit_check = twitter.get_application_rate_limit_status()['resources']['statuses']['/statuses/user_timeline']['remaining']
            print ('.......y el límite de ratio de acceso al API actual es: ', rate_limit_check)
            if rate_limit_check<5:
                print ('Quedan menos de 5 llamadas API ... pausando por 5 minutoss')
                time.sleep(300) #PAUSA DE 300 SEGUNDOS
                rate_limit = twitter.get_application_rate_limit_status()['resources']['statuses']['/statuses/user_timeline']['remaining']
                print ('.......Este es el límite de ratio de acceso al API después de una pausa de 5 minutos: ', rate_limit)
                #si el rate_limit_check == 900:
                #    rate_limit = 900

    #if twitter.get_application_rate_limit_status()['resources']['search']['/search/tweets']['remaining']<5:
    if rate_limit < 5:
        print ('Quedan menos de 5 llamadas API estimadas ... pausando por 5 minutos...')
        time.sleep(300) #PAUSA POR 300 SEGUNDOS
      
        
elapsed = timeit.default_timer() - start_time
print ('# de minutos: ', elapsed/60)
print ("Número de nuevos tweets añadidos en esta ejecución: ", tweets.count_documents({}) - starting_count)
print ("Número de tweets actuales en la BD: ", tweets.count_documents({}), '\n', '\n')

###### PARTE 7: Impresión del número de tweets en la base de datos por cuenta. ######  

for org in db.tweets.aggregate([
    {"$group":{"_id":"$screen_name", "sum":{"$sum":1}}} 
    ]):
    print (org['_id'], org['sum'])
# Out:
#  900 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  @AJEnglish -- index:  0
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  900
# ..........llamadas a la API restantes estimadas:  899
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  @AJEnglish -- 200  TWEETS
# --- STARTING PAGE 2 ...llamadas a la API restantes estimadas:  899
# ..........llamadas a la API restantes estimadas:  898
# --- PÁGINA FINALIZADA  2  PARA ORGANIZAR  @AJEnglish -- 200  TWEETS
# --- STARTING PAGE 3 ...llamadas a la API restantes estimadas:  898
# ..........llamadas a la API restantes estimadas:  897
# --- PÁGINA FINALIZADA  3  PARA ORGANIZAR  @AJEnglish -- 200  TWEETS
# --- STARTING PAGE 4 ...llamadas a la API restantes estimadas:  897
# ..........llamadas a la API restantes estimadas:  896
# --- PÁGINA FINALIZADA  4  PARA ORGANIZAR  @AJEnglish -- 200  TWEETS
# --- STARTING PAGE 5 ...llamadas a la API restantes estimadas:  896
# ..........llamadas a la API restantes estimadas:  895
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582114329129787392" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582114329129787392'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582114329129787392" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582114233461878785" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582114233461878785'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582114233461878785" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582110522375290890" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582110522375290890'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582110522375290890" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582106751196856332" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582106751196856332'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582106751196856332" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582103605795991552" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582103605795991552'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582103605795991552" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582103330976804865" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582103330976804865'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582103330976804865" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582102930349490200" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582102930349490200'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582102930349490200" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582095351653203991" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582095351653203991'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582095351653203991" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582093389071540224" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582093389071540224'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582093389071540224" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582091576083349522" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582091576083349522'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582091576083349522" }'}
#
# --- PÁGINA FINALIZADA  5  PARA ORGANIZAR  @AJEnglish -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  895 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  @BBCBreaking -- index:  1
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  895
# ..........llamadas a la API restantes estimadas:  894
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582046993966170123" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582046993966170123'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582046993966170123" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581955128487092225" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581955128487092225'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581955128487092225" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581952829132263424" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581952829132263424'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581952829132263424" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581877654185078785" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581877654185078785'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581877654185078785" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581868406747250688" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581868406747250688'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581868406747250688" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581309651022671873" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581309651022671873'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581309651022671873" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581195035760287745" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581195035760287745'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581195035760287745" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581183771822690305" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581183771822690305'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581183771822690305" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580973594498453504" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1580973594498453504'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580973594498453504" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580965102391504904" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1580965102391504904'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580965102391504904" }'}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  @BBCBreaking -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  894 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  @IsraelRadar_com -- index:  2
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  894
# ..........llamadas a la API restantes estimadas:  893
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582091688893640706" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582091688893640706'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582091688893640706" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582085760605642753" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582085760605642753'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582085760605642753" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582072282171994112" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582072282171994112'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582072282171994112" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582065789703958528" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582065789703958528'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582065789703958528" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581980114111279104" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581980114111279104'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581980114111279104" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581734790260461568" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581734790260461568'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581734790260461568" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581638548670726144" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581638548670726144'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581638548670726144" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581635863338840064" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581635863338840064'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581635863338840064" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581560152372940801" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581560152372940801'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581560152372940801" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581291336451297281" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581291336451297281'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581291336451297281" }'}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  @IsraelRadar_com -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  893 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  @cnnbrk -- index:  3
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  893
# ..........llamadas a la API restantes estimadas:  892
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582091009605132288" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582091009605132288'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582091009605132288" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582060678902206464" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582060678902206464'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582060678902206464" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582046657423605760" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1582046657423605760'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1582046657423605760" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581995606586712064" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581995606586712064'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581995606586712064" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581875658870775809" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581875658870775809'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581875658870775809" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581431845916319744" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581431845916319744'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581431845916319744" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581013527493345280" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581013527493345280'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581013527493345280" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581006897972641801" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1581006897972641801'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1581006897972641801" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580974294859132929" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1580974294859132929'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580974294859132929" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580934597436588034" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '1580934597436588034'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "1580934597436588034" }'}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  @cnnbrk -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
#
#  892 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  @guardian -- index:  4
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  892
# ..........llamadas a la API restantes estimadas:  891
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 2 ...llamadas a la API restantes estimadas:  891
# ..........llamadas a la API restantes estimadas:  890
# --- PÁGINA FINALIZADA  2  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 3 ...llamadas a la API restantes estimadas:  890
# ..........llamadas a la API restantes estimadas:  889
# --- PÁGINA FINALIZADA  3  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 4 ...llamadas a la API restantes estimadas:  889
# ..........llamadas a la API restantes estimadas:  888
# --- PÁGINA FINALIZADA  4  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 5 ...llamadas a la API restantes estimadas:  888
# ..........llamadas a la API restantes estimadas:  887
# --- PÁGINA FINALIZADA  5  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 6 ...llamadas a la API restantes estimadas:  887
# ..........llamadas a la API restantes estimadas:  886
# --- PÁGINA FINALIZADA  6  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 7 ...llamadas a la API restantes estimadas:  886
# ..........llamadas a la API restantes estimadas:  885
# --- PÁGINA FINALIZADA  7  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 8 ...llamadas a la API restantes estimadas:  885
# ..........llamadas a la API restantes estimadas:  884
# --- PÁGINA FINALIZADA  8  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 9 ...llamadas a la API restantes estimadas:  884
# ..........llamadas a la API restantes estimadas:  883
# --- PÁGINA FINALIZADA  9  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 10 ...llamadas a la API restantes estimadas:  883
# ..........llamadas a la API restantes estimadas:  882
# --- PÁGINA FINALIZADA  10  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 11 ...llamadas a la API restantes estimadas:  882
# ..........llamadas a la API restantes estimadas:  881
# --- PÁGINA FINALIZADA  11  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 12 ...llamadas a la API restantes estimadas:  881
# ..........llamadas a la API restantes estimadas:  880
# --- PÁGINA FINALIZADA  12  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 13 ...llamadas a la API restantes estimadas:  880
# ..........llamadas a la API restantes estimadas:  879
# --- PÁGINA FINALIZADA  13  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 14 ...llamadas a la API restantes estimadas:  879
# ..........llamadas a la API restantes estimadas:  878
# --- PÁGINA FINALIZADA  14  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 15 ...llamadas a la API restantes estimadas:  878
# ..........llamadas a la API restantes estimadas:  877
# --- PÁGINA FINALIZADA  15  PARA ORGANIZAR  @guardian -- 200  TWEETS
# --- STARTING PAGE 16 ...llamadas a la API restantes estimadas:  877
# Error reading id @guardian, exception: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# No hubo tweets devueltos........Desplazandose al siguiente ID
#
#  877 # llamadas a la API restantes
#
# Leyendo tweets enviados por:  @terrorismwatch1 -- index:  5
# --- STARTING PAGE 1 ...llamadas a la API restantes estimadas:  877
# ..........llamadas a la API restantes estimadas:  876
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "426554031801376768" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '426554031801376768'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "426554031801376768" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "389626066064932864" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '389626066064932864'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "389626066064932864" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270435928877694977" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270435928877694977'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270435928877694977" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270435845159411712" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270435845159411712'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270435845159411712" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270433458067746816" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270433458067746816'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270433458067746816" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432994370666496" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270432994370666496'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432994370666496" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432891991887872" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270432891991887872'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432891991887872" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432815190007808" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270432815190007808'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432815190007808" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432599120420864" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270432599120420864'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432599120420864" }'}
#
# E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432279434780672" }, full error: {'index': 0, 'code': 11000, 'keyPattern': {'id_str': 1}, 'keyValue': {'id_str': '270432279434780672'}, 'errmsg': 'E11000 duplicate key error collection: DB_TFM_ECR.Tweetters index: id_str_1 dup key: { id_str: "270432279434780672" }'}
#
# --- PÁGINA FINALIZADA  1  PARA ORGANIZAR  @terrorismwatch1 -- 200  TWEETS
#
# ********************Hay 10 duplicados....saltando al siguiente ID ********************
#
# # de minutos:  6.937702306666567
# Número de nuevos tweets añadidos en esta ejecución:  4068
# Número de tweets actuales en la BD:  22684
